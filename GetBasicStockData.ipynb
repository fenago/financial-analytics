# %%
# https://pypi.org/project/yfinance/
import yfinance as yf

# %%
jpm = yf.Ticker('JPM')

# %%
# Get stock data
jpm.info
# Out:
# {'zip': '10179',
#  'sector': 'Financial Services',
#  'fullTimeEmployees': 265790,
# ...

# %%
# Access Historical Market Data
hist = jpm.history(period='max')
hist
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 1980-03-17    0.000000    1.179639    1.154088    1.158346     62775
# 1980-03-18    0.000000    1.175381    1.158347    1.166864     64125
# 1980-03-19    0.000000    1.188157    1.175381    1.183899     40500
# 1980-03-20    0.000000    1.183898    1.171123    1.175381     18900
# 1980-03-21    0.000000    1.200933    1.175381    1.200933     97200
# ...                ...         ...         ...         ...       ...
# 2021-11-17  165.210007  165.559998  163.389999  164.470001   9909600
# 2021-11-18  164.389999  164.850006  162.559998  163.050003   8122500
# 2021-11-19  161.300003  162.110001  159.449997  160.919998  12171000
# 2021-11-22  164.160004  165.979996  162.990005  164.350006  14549900
# 2021-11-23  165.500000  167.940002  165.369995  167.850006   6956737
#
#             Dividends  Stock Splits
# Date
# 1980-03-17        0.0           0.0
# 1980-03-18        0.0           0.0
# ...

# %%
# Dividends and Splits
jpm.actions
# Out:
#             Dividends  Stock Splits
# Date
# 1982-04-16   0.000000           1.5
# 1984-03-09   0.196667           0.0
# 1984-04-16   0.000000           1.5
# 1984-06-11   0.196667           0.0
# 1984-09-10   0.196667           0.0
# ...               ...           ...
# 2020-10-05   0.900000           0.0
# 2021-01-05   0.900000           0.0
# 2021-04-05   0.900000           0.0
# 2021-07-02   0.900000           0.0
# 2021-10-05   1.000000           0.0
#
# [156 rows x 2 columns]

# %%
# Show dividends only
jpm.dividends
# Out:
# Date
# 1984-03-09    0.196667
# 1984-06-11    0.196667
# 1984-09-10    0.196667
# 1984-12-10    0.196667
# 1985-03-11    0.206667
#                 ...
# 2020-10-05    0.900000
# 2021-01-05    0.900000
# 2021-04-05    0.900000
# 2021-07-02    0.900000
# 2021-10-05    1.000000
# Name: Dividends, Length: 152, dtype: float64

# %%
jpm.splits
# Out:
# Date
# 1982-04-16    1.5
# 1984-04-16    1.5
# 1998-06-15    2.0
# 2000-06-12    1.5
# Name: Stock Splits, dtype: float64

# %%
jpm.financials
# Out:
#                                             2020-12-31      2019-12-31  \
# Research Development                              None            None
# Effect Of Accounting Charges                      None            None
# Income Before Tax                        35407000000.0   44545000000.0
# Minority Interest                                 None            None
# Net Income                               29131000000.0   36431000000.0
# Selling General Administrative           60715000000.0   60182000000.0
# Gross Profit                            102063000000.0  109813000000.0
# Ebit                                               0.0             0.0
# Operating Income                         36522000000.0   44784000000.0
# Other Operating Expenses                  4826000000.0    4847000000.0
# Interest Expense                                  None            None
# Extraordinary Items                               None            None
# ...

# %%
jpm.quarterly_financials
# Out:
#                                            2021-09-30     2021-06-30  \
# Research Development                             None           None
# Effect Of Accounting Charges                     None           None
# Income Before Tax                       14111000000.0  15097000000.0
# Minority Interest                                None           None
# Net Income                              11687000000.0  11948000000.0
# Selling General Administrative          15904000000.0  16403000000.0
# Gross Profit                            31174000000.0  32764000000.0
# Ebit                                              0.0            0.0
# Operating Income                        14187000000.0  15282000000.0
# Other Operating Expenses                 1083000000.0   1079000000.0
# Interest Expense                                 None           None
# Extraordinary Items                              None           None
# Non Recurring                                    None           None
# ...

# %%
# Major holders
jpm.major_holders
# Out:
#         0                                      1
# 0   0.92%        % of Shares Held by All Insider
# 1  71.86%       % of Shares Held by Institutions
# 2  72.53%        % of Float Held by Institutions
# 3    4026  Number of Institutions Holding Shares

# %%
# Institutional Holders
jpm.institutional_holders
# Out:
#                              Holder     Shares Date Reported   % Out  \
# 0        Vanguard Group, Inc. (The)  260594509    2021-09-29  0.0882
# 1                    Blackrock Inc.  192291314    2021-09-29  0.0651
# 2          State Street Corporation  139443025    2021-09-29  0.0472
# 3           Capital World Investors   74302154    2021-09-29  0.0251
# 4       Bank of America Corporation   51898980    2021-09-29  0.0176
# 5  Wellington Management Group, LLP   51253306    2021-09-29  0.0173
# 6     Geode Capital Management, LLC   47118935    2021-09-29  0.0159
# 7                          FMR, LLC   45142343    2021-09-29  0.0153
# 8   Capital International Investors   38817564    2021-09-29  0.0131
# 9                    Morgan Stanley   38201840    2021-09-29  0.0129
#
#          Value
# 0  42656715178
# 1  31476165188
# 2  22825428762
# 3  12162519588
# 4   8495344036
# 5   8389653659
# 6   7712898470
# 7   7389350125
# 8   6354047051
# 9   6253259189

# %%
jpm.balance_sheet
# Out:
#                              2020-12-31    2019-12-31    2018-12-31  \
# Intangible Assets          4.180000e+09  5.518000e+09  6.878000e+09
# Capital Surplus            8.839400e+10  8.852200e+10  8.916200e+10
# Total Liab                 3.106717e+12  2.426049e+12  2.366017e+12
# Total Stockholder Equity   2.492910e+11  2.343370e+11  2.304470e+11
# Other Current Liab         9.955800e+10  7.556900e+10  1.030040e+11
# Total Assets               3.386071e+12  2.687379e+12  2.622532e+12
# Common Stock               4.105000e+09  4.105000e+09  4.105000e+09
# Other Current Assets       2.356370e+11  2.322790e+11  2.074050e+11
# Retained Earnings          2.369900e+11  2.232110e+11  1.992020e+11
# Other Liab                 2.421000e+09           NaN           NaN
# Good Will                  4.924800e+10  4.782300e+10  4.747100e+10
# Treasury Stock            -8.019800e+10 -8.150100e+10 -6.202200e+10
# Other Assets               1.146272e+12  1.109292e+12  1.081167e+12
# ...

# %%
jpm.quarterly_balance_sheet
# Out:
#                              2021-09-30    2021-06-30    2021-03-31  \
# Intangible Assets          6.253000e+09  5.399000e+09  5.345000e+09
# Capital Surplus            8.835700e+10  8.819400e+10  8.800500e+10
# Total Liab                 3.467535e+12  3.397870e+12  3.408622e+12
# Total Stockholder Equity   2.552030e+11  2.535480e+11  2.491510e+11
# Other Current Liab         1.260580e+11  1.278220e+11  1.309090e+11
# Total Assets               3.757576e+12  3.684256e+12  3.689336e+12
# Common Stock               4.105000e+09  4.105000e+09  4.105000e+09
# Other Current Assets       2.916130e+11  2.864810e+11  2.690330e+11
# Retained Earnings          2.652760e+11  2.569830e+11  2.481510e+11
# Other Liab                 2.305000e+09  2.998000e+09  2.519000e+09
# Good Will                  5.031300e+10  4.925600e+10  4.924300e+10
# Treasury Stock            -1.025350e+11 -9.573400e+10 -9.111000e+10
# Other Assets               1.231459e+12  1.254801e+12  1.214132e+12
# ...

# %%
jpm.cashflow
# jpm.quarterly_cashflow
# Out:
#                                              2020-12-31    2019-12-31  \
# Investments                               -1.807520e+11 -1.297720e+11
# Change To Liabilities                      7.827000e+09 -3.520000e+08
# Total Cashflows From Investing Activities -2.619120e+11 -5.205900e+10
# Net Borrowings                             1.094400e+10 -3.145000e+10
# Total Cash From Financing Activities       5.966450e+11  3.298700e+10
# Change To Operating Activities             1.403000e+10 -5.971700e+10
# Net Income                                 2.913100e+10  3.643100e+10
# Change In Cash                             2.639780e+11 -1.516200e+10
# Repurchase Of Stock                       -6.517000e+09 -2.400100e+10
# Effect Of Exchange Rate                    9.155000e+09 -1.820000e+08
# Total Cash From Operating Activities      -7.991000e+10  4.092000e+09
# Depreciation                               8.614000e+09  8.368000e+09
# ...

# %%
# Earnings
jpm.earnings
jpm.quarterly_earnings
# Out:
#            Revenue     Earnings
# Year
# 2017   94745000000  24441000000
# 2018  103744000000  32474000000
# 2019  109813000000  36431000000
# 2020  102063000000  29131000000

# %%
jpm.sustainability
# Out:
#                           Value
# 2021-9
# palmOil                   False
# controversialWeapons      False
# gambling                  False
# socialScore               16.35
# nuclear                   False
# furLeather                False
# alcoholic                 False
# gmo                       False
# catholic                  False
# socialPercentile           None
# peerCount                   165
# governanceScore           10.55
# environmentPercentile      None
# animalTesting             False
# tobacco                   False
# totalEsg                     28
# highestControversy            3
# esgPerformance         AVG_PERF
# coal                      False
# pesticides                False
# adult                     False
# percentile                52.24
# peerGroup                 Banks
# smallArms                 False
# environmentScore           1.11
# governancePercentile       None
# militaryContract          False

# %%
# Analyst Recommendations
jpm.recommendations
# Out:
#                                Firm     To Grade From Grade Action
# Date
# 2012-02-29 07:34:00       Citigroup          Buy              main
# 2012-03-01 07:29:00       Citigroup          Buy              main
# 2012-03-08 06:00:00  Morgan Stanley   Overweight              main
# 2012-03-19 06:12:00  Morgan Stanley   Overweight              main
# 2012-03-27 07:24:00    Bank oferica          Buy              main
# ...                             ...          ...        ...    ...
# 2021-07-29 13:04:59  Morgan Stanley  Underweight              main
# 2021-10-11 13:36:33       Jefferies          Buy              main
# 2021-10-14 11:29:52     RBC Capital   Outperform              main
# 2021-10-15 13:40:50        Barclays   Overweight              main
# 2021-10-25 11:21:52     Wells Fargo   Overweight              main
#
# [224 rows x 4 columns]

# %%
jpm.calendar
# Out:
#                                 Value
# Earnings Date     2022-01-14 13:30:00
# Earnings Average                 2.94
# Earnings Low                     2.76
# Earnings High                    3.32
# Revenue Average           29543400000
# Revenue Low               29024000000
# Revenue High              30795000000

# %%
# International Securities Identification Number
jpm.isin
# Out:
# 'US46625H1005'

# %%
# Options expirations
jpm.options
# Out:
# ('2021-11-26',
#  '2021-12-03',
#  '2021-12-10',
#  '2021-12-17',
#  '2021-12-23',
#  '2021-12-31',
#  '2022-01-21',
#  '2022-02-18',
#  '2022-03-18',
#  '2022-04-14',
#  '2022-06-17',
#  '2023-01-20',
#  '2024-01-19')

# %%
jpm.news
# Out:
# [{'uuid': 'cda210d5-7010-3e72-92ab-c7d340a08bdd',
#   'title': 'JPMorgan wins appeal against insurers over Bear Stearns settlement',
#   'publisher': 'Reuters',
#   'link': 'https://finance.yahoo.com/news/jpmorgan-wins-appeal-against-insurers-164528820.html',
#   'providerPublishTime': 1637685928,
#   'type': 'STORY'},
#  {'uuid': 'a00d91b8-d7a7-311f-a504-b7b66b8a36ae',
#   'title': 'JPMorgan Chase makes move to 1900 N. Akard official',
#   'publisher': 'American City Business Journals',
#   'link': 'https://finance.yahoo.com/m/a00d91b8-d7a7-311f-a504-b7b66b8a36ae/jpmorgan-chase-makes-move-to.html',
#   'providerPublishTime': 1637685166,
#   'type': 'STORY'},
#  {'uuid': '563a25ba-4d4f-39e9-a1cd-ac2ea01cda84',
#   'title': 'JPMorgan Chase to Present at the Goldman Sachs U.S. Financial Services Conference',
#   'publisher': 'Business Wire',
#   'link': 'https://finance.yahoo.com/news/jpmorgan-chase-present-goldman-sachs-162800160.html',
#   'providerPublishTime': 1637684880,
# ...

# %%
import yfinance as yf
data = yf.download("JPM SPY AAPL", start="2021-11-15", end="2021-11-22")
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
data = yf.download(  # or pdr.get_data_yahoo(...
        # tickers list or string as well
        tickers = "JPM SPY AAPL MSFT",

        # use "period" instead of start/end
        # valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
        # (optional, default is '1mo')
        period = "ytd",

        # fetch data by interval (including intraday if period < 60 days)
        # valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
        # (optional, default is '1d')
        interval = "1d",

        # group by ticker (to access via data['SPY'])
        # (optional, default is 'column')
        group_by = 'ticker',

        # adjust all OHLC automatically
        # (optional, default is False)
        auto_adjust = True,

        # download pre/post regular market hours data
        # (optional, default is False)
        prepost = True,

        # use threads for mass downloading? (True/False/Integer)
        # (optional, default is True)
        threads = True,

        # proxy URL scheme use use when downloading?
        # (optional, default is None)
        proxy = None
    )
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
data.head()
# Out:
#                   MSFT                                                \
#                   Open        High         Low       Close    Volume
# Date
# 2021-01-04  220.680180  221.146274  213.024353  215.880417  37130100
# 2021-01-05  215.453990  216.703525  213.906960  216.088669  23823000
# 2021-01-06  210.406305  214.690401  210.178221  210.485641  35930700
# 2021-01-07  212.260747  217.516693  211.933503  216.475418  27694500
# 2021-01-08  216.862199  218.746414  215.225921  217.794388  22956200
#
#                   AAPL                                                 \
#                   Open        High         Low       Close     Volume
# Date
# 2021-01-04  132.701930  132.791375  125.983346  128.617111  143301900
# 2021-01-05  128.100285  130.932829  127.643097  130.207291   97664900
# 2021-01-06  126.937466  130.247065  125.605672  125.824326  155088000
# 2021-01-07  127.573546  130.823515  127.076610  130.117859  109578200
# ...

# %%
data.to_csv('output_datafile.csv')
